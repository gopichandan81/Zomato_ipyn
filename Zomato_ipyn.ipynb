# %%
df=pd.read_csv('/content/zomato.csv')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.head(5)
# Out:
#    Unnamed: 0  Restaurant ID Restaurant Name  Number of Orders   Price  \
# 0           0              1   Spicy Delight               450  150.50
# 1           1              2     Urban Diner               320  200.00
# 2           2              3    Green Garden               280  250.75
# 3           3              4  Taste of Italy               500  300.20
# 4           4              5     Sushi World               350  350.00
#
#            City  Rating             Food Name
# 0   Koramangala     4.5           Masala Dosa
# 1   Indiranagar     4.0        Butter Chicken
# 2    Whitefield     3.8  Paneer Butter Masala
# 3       MG Road     4.7       Chicken Biryani
# 4  Brigade Road     4.2       Vegetable Pulao

# %%
df.shape
# Out:
# (50, 8)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Restaurant ID', 'Restaurant Name', 'Number of Orders',
#        'Price', 'City', 'Rating', 'Food Name'],
#       dtype='object')

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df.head(5)
# Out:
#    Restaurant ID Restaurant Name  Number of Orders   Price          City  \
# 0              1   Spicy Delight               450  150.50   Koramangala
# 1              2     Urban Diner               320  200.00   Indiranagar
# 2              3    Green Garden               280  250.75    Whitefield
# 3              4  Taste of Italy               500  300.20       MG Road
# 4              5     Sushi World               350  350.00  Brigade Road
#
#    Rating             Food Name
# 0     4.5           Masala Dosa
# 1     4.0        Butter Chicken
# 2     3.8  Paneer Butter Masala
# 3     4.7       Chicken Biryani
# 4     4.2       Vegetable Pulao

# %%
df.City.value_counts()
# Out:
# City
# MG Road               2
# Koramangala           1
# Banerghatta Road      1
# Nagawara              1
# RT Nagar              1
# Richmond Town         1
# Sadashivanagar        1
# Seshadripuram         1
# Vijayanagar           1
# Chandra Layout        1
# Varthur               1
# Brookefield           1
# Hulimavu              1
# Kumaraswamy Layout    1
# Kammanahalli          1
# Lalbagh               1
# Vasanth Nagar         1
# Peenya                1
# Hoskote               1
# Kengeri               1
# Yelahanka             1
# Banaswadi             1
# Majestic              1
# Old Madras Road       1
# Hennur                1
# KR Puram              1
# Indiranagar           1
# Rajajinagar           1
# Whitefield            1
# Brigade Road          1
# Jayanagar             1
# JP Nagar              1
# Banashankari          1
# HSR Layout            1
# BTM Layout            1
# Marathahalli          1
# Malleshwaram          1
# Frazer Town           1
# ...

# %%
df.Rating.value_counts()
# Out:
# Rating
# 4.0    6
# 3.8    5
# 4.2    5
# 3.9    5
# 4.6    5
# 4.5    4
# 4.1    4
# 4.4    4
# 4.7    3
# 4.3    3
# 4.8    3
# 3.7    3
# Name: count, dtype: int64

# %%
df['Food Name'].value_counts().plot(kind='pie', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6','#c4e17f','#76d7c4','#f7b7a3','#d4a5a5']*5, autopct='%.2f%%', figsize=(8, 8), startangle=90)
plt.show()

# %%
df['Food Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Food Name'>

# %%
df['Rating'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
df['City'].value_counts().plot(kind='pie', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99','#c2c2f0','#ffb3e6','#c4e17f','#76d7c4','#f7b7a3','#d4a5a5']*5, autopct='%.2f%%', figsize=(8, 8), startangle=90)
plt.show()

# %%
df['Rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Rating'>

# %%
df['Number of Orders'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Number of Orders'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Number of Orders'>

# %%
df['Restaurant Name'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['Restaurant Name'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Restaurant Name'>
